# %% [markdown]
# So far, we've been keeping track of match locations using character offsets. But this won't work once we convert the TEI to HTML.
# So we have to add markers in the TEI which we can use later to highlight matches.
#
# Let's use [the anchor tag](https://www.tei-c.org/release/doc/tei-p5-doc/en/html/ref-anchor.html).

# %%
import pandas as pd
import re
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('../../../criticism-analysis/fw-matches.csv')

# %% [markdown]
# Split up FW into chunks according to these locations.
#
# If a location is used more than once, we'll have to find a way to handle that.

# %%
df['Text A'][0]
# Out:
# '../texts/corpus-joyce-finnegans-wake-tei/finnegans-wake-corrected.xml'

# %%
with open("./../finnegans-wake-corrected.xml") as f: 
    fw = f.read()

# %%
len(fw)
# Out:
# 1465021

# %%
# Melt the data frame such that each match is its own row
melted = {}
for i, row in df.iterrows(): 
    locs = eval(row['Locations in A']) # Is a string
    for loc in locs: 
        data = row.to_dict()
        thisLoc = {"start": loc[0], "end": loc[1]}
        # Make one for each of start, end
        for locType in thisLoc: 
            data = row.to_dict() # Don't really know why I have to do this
            data['loc'] = thisLoc[locType]
            data['locType'] = locType
            index = str(i) + str(loc) + locType
            melted[index] = data

# %%
dfMelted = pd.DataFrame(melted).T

# %%
tagLocations = [match.span() for match in list(re.finditer('<.*?>', fw))]

# %%
def avoidTags(loc, tagLocations=tagLocations): 
    """ If a given location is inside a tag, move it until it's outside. """
    for tagStart, tagEnd in tagLocations: 
        if loc >= tagStart and loc <= tagEnd: 
            # This location is inside a tag
            print(loc, ' is inside a tag.')
            return tagEnd
    return loc

# %%
avoidTags(585861)
# Out:
# 585861  is inside a tag.
# 585891

# %%
dfMelted['loc'].apply(avoidTags)
# Out:
# 1208681  is inside a tag.
# 940508  is inside a tag.
# 425458  is inside a tag.
# 1246846  is inside a tag.
# 657372  is inside a tag.
# 279507  is inside a tag.
# 343592  is inside a tag.
# 350877  is inside a tag.
# 380573  is inside a tag.
# 1458924  is inside a tag.
# 1460047  is inside a tag.
# 1153319  is inside a tag.
# 962339  is inside a tag.
# 776232  is inside a tag.
# 1146398  is inside a tag.
# 445923  is inside a tag.
# 452075  is inside a tag.
# 693604  is inside a tag.
# 1108743  is inside a tag.
# 1460034  is inside a tag.
# 530677  is inside a tag.
# 783383  is inside a tag.
# 830205  is inside a tag.
# 830326  is inside a tag.
# 280329  is inside a tag.
# 281386  is inside a tag.
# 385037  is inside a tag.
# 405233  is inside a tag.
# 429706  is inside a tag.
# 961731  is inside a tag.
# 962339  is inside a tag.
# 1346423  is inside a tag.
# 431766  is inside a tag.
# 431766  is inside a tag.
# 274032  is inside a tag.
# 1125421  is inside a tag.
# 431766  is inside a tag.
# 331088  is inside a tag.
# 330878  is inside a tag.
# 646366  is inside a tag.
# 1428771  is inside a tag.
# 517886  is inside a tag.
# 279486  is inside a tag.
# 274141  is inside a tag.
# 923112  is inside a tag.
# 1111381  is inside a tag.
# 883236  is inside a tag.
# 1246901  is inside a tag.
# 279507  is inside a tag.
# 279570  is inside a tag.
# 282454  is inside a tag.
# 1077485  is inside a tag.
# 344620  is inside a tag.
# 1418255  is inside a tag.
# 1338876  is inside a tag.
# 670716  is inside a tag.
# 431766  is inside a tag.
# 501261  is inside a tag.
# 62065  is inside a tag.
# 328525  is inside a tag.
# 1291025  is inside a tag.
# 690716  is inside a tag.
# 431766  is inside a tag.
# 580670  is inside a tag.
# 233819  is inside a tag.
# 234081  is inside a tag.
# 287752  is inside a tag.
# 982867  is inside a tag.
# 431766  is inside a tag.
# 1387513  is inside a tag.
# 431766  is inside a tag.
# 1419780  is inside a tag.
# 385037  is inside a tag.
# 431766  is inside a tag.
# 697813  is inside a tag.
# 107653  is inside a tag.
# 1077485  is inside a tag.
# 1077673  is inside a tag.
# 25042  is inside a tag.
# 1457325  is inside a tag.
# 431766  is inside a tag.
# 385037  is inside a tag.
# 388695  is inside a tag.
# 1279162  is inside a tag.
# 1182264  is inside a tag.
# 1077673  is inside a tag.
# 1337013  is inside a tag.
# 1337068  is inside a tag.
# 392641  is inside a tag.
# 347640  is inside a tag.
# 1247091  is inside a tag.
# 406717  is inside a tag.
# 406800  is inside a tag.
# 351529  is inside a tag.
# 382521  is inside a tag.
# 596908  is inside a tag.
# 431777  is inside a tag.
# 429634  is inside a tag.
# 552053  is inside a tag.
# 328525  is inside a tag.
# 962339  is inside a tag.
# 960877  is inside a tag.
# 960972  is inside a tag.
# 962339  is inside a tag.
# 35249  is inside a tag.
# 405233  is inside a tag.
# 996259  is inside a tag.
# 996388  is inside a tag.
# 431766  is inside a tag.
# 1344656  is inside a tag.
# 350870  is inside a tag.
# 381092  is inside a tag.
# 431766  is inside a tag.
# 282454  is inside a tag.
# 465054  is inside a tag.
# 1457295  is inside a tag.
# 643  is inside a tag.
# 544290  is inside a tag.
# 992707  is inside a tag.
# 1043910  is inside a tag.
# 1420237  is inside a tag.
# 431766  is inside a tag.
# 643  is inside a tag.
# 32087  is inside a tag.
# 363913  is inside a tag.
# 883258  is inside a tag.
# 950395  is inside a tag.
# 638649  is inside a tag.
# 639201  is inside a tag.
# 1123654  is inside a tag.
# 1123723  is inside a tag.
# 169262  is inside a tag.
# 425506  is inside a tag.
# 425507  is inside a tag.
# 1144196  is inside a tag.
# 643  is inside a tag.
# 1336838  is inside a tag.
# 1338876  is inside a tag.
# 1372501  is inside a tag.
# 357064  is inside a tag.
# 643  is inside a tag.
# 406717  is inside a tag.
# 406800  is inside a tag.
# 280329  is inside a tag.
# 67122  is inside a tag.
# 593864  is inside a tag.
# 1458924  is inside a tag.
# 775900  is inside a tag.
# 781132  is inside a tag.
# 277380  is inside a tag.
# 281960  is inside a tag.
# 813  is inside a tag.
# 411297  is inside a tag.
# 1407693  is inside a tag.
# 351529  is inside a tag.
# 771028  is inside a tag.
# 173986  is inside a tag.
# 25690  is inside a tag.
# 1238422  is inside a tag.
# 647442  is inside a tag.
# 643  is inside a tag.
# 35155  is inside a tag.
# 873514  is inside a tag.
# 1151741  is inside a tag.
# 883941  is inside a tag.
# 884065  is inside a tag.
# 643  is inside a tag.
# 405233  is inside a tag.
# 674503  is inside a tag.
# 1171042  is inside a tag.
# 431766  is inside a tag.
# 1291025  is inside a tag.
# 675901  is inside a tag.
# 702832  is inside a tag.
# 282751  is inside a tag.
# 501261  is inside a tag.
# 495575  is inside a tag.
# 431766  is inside a tag.
# 1146387  is inside a tag.
# 1246846  is inside a tag.
# 1247091  is inside a tag.
# 282454  is inside a tag.
# 109583  is inside a tag.
# 648991  is inside a tag.
# 771028  is inside a tag.
# 425458  is inside a tag.
# 400558  is inside a tag.
# 67122  is inside a tag.
# 431766  is inside a tag.
# 1214427  is inside a tag.
# 257736  is inside a tag.
# 353747  is inside a tag.
# 1000275  is inside a tag.
# 407240  is inside a tag.
# 407328  is inside a tag.
# 575809  is inside a tag.
# 406943  is inside a tag.
# 111995  is inside a tag.
# 960253  is inside a tag.
# 1246846  is inside a tag.
# 1418255  is inside a tag.
# 595254  is inside a tag.
# 620991  is inside a tag.
# 960799  is inside a tag.
# 975494  is inside a tag.
# 775417  is inside a tag.
# 392582  is inside a tag.
# 431766  is inside a tag.
# 1123654  is inside a tag.
# 1123747  is inside a tag.
# 242657  is inside a tag.
# 813  is inside a tag.
# 648810  is inside a tag.
# 510212  is inside a tag.
# 242675  is inside a tag.
# 921210  is inside a tag.
# 996388  is inside a tag.
# 643  is inside a tag.
# 883494  is inside a tag.
# 610076  is inside a tag.
# 615669  is inside a tag.
# 4642  is inside a tag.
# 960131  is inside a tag.
# 1407682  is inside a tag.
# 171652  is inside a tag.
# 173986  is inside a tag.
# 890849  is inside a tag.
# 452015  is inside a tag.
# 81476  is inside a tag.
# 463590  is inside a tag.
# 1214450  is inside a tag.
# 429706  is inside a tag.
# 431766  is inside a tag.
# 811368  is inside a tag.
# 962339  is inside a tag.
# 873627  is inside a tag.
# 1407678  is inside a tag.
# 1419895  is inside a tag.
# 1420127  is inside a tag.
# 392567  is inside a tag.
# 392582  is inside a tag.
# 251770  is inside a tag.
# 328525  is inside a tag.
# 1065778  is inside a tag.
# 328525  is inside a tag.
# 441817  is inside a tag.
# 382521  is inside a tag.
# 995144  is inside a tag.
# 282751  is inside a tag.
# 1123436  is inside a tag.
# 328525  is inside a tag.
# 1407702  is inside a tag.
# 0(334922, 335011)start       334922
# 0(334922, 335011)end         335011
# 1(478048, 478132)start       478048
# 1(478048, 478132)end         478132
# 2(5475, 5947)start             5475
#                               ...
# 1138(408888, 408993)end      408993
# 1138(788319, 788414)start    788319
# 1138(788319, 788414)end      788414
# 1139(366179, 366282)start    366179
# 1139(366179, 366282)end      366282
# Name: loc, Length: 5540, dtype: int64

# %%
(dfMelted['loc'] == dfMelted['loc'].apply(avoidTags)).value_counts()
# Out:
# 1208681  is inside a tag.
# 940508  is inside a tag.
# 425458  is inside a tag.
# 1246846  is inside a tag.
# 657372  is inside a tag.
# 279507  is inside a tag.
# 343592  is inside a tag.
# 350877  is inside a tag.
# 380573  is inside a tag.
# 1458924  is inside a tag.
# 1460047  is inside a tag.
# 1153319  is inside a tag.
# 962339  is inside a tag.
# 776232  is inside a tag.
# 1146398  is inside a tag.
# 445923  is inside a tag.
# 452075  is inside a tag.
# 693604  is inside a tag.
# 1108743  is inside a tag.
# 1460034  is inside a tag.
# 530677  is inside a tag.
# 783383  is inside a tag.
# 830205  is inside a tag.
# 830326  is inside a tag.
# 280329  is inside a tag.
# 281386  is inside a tag.
# 385037  is inside a tag.
# 405233  is inside a tag.
# 429706  is inside a tag.
# 961731  is inside a tag.
# 962339  is inside a tag.
# 1346423  is inside a tag.
# 431766  is inside a tag.
# 431766  is inside a tag.
# 274032  is inside a tag.
# 1125421  is inside a tag.
# 431766  is inside a tag.
# 331088  is inside a tag.
# 330878  is inside a tag.
# 646366  is inside a tag.
# 1428771  is inside a tag.
# 517886  is inside a tag.
# 279486  is inside a tag.
# 274141  is inside a tag.
# 923112  is inside a tag.
# 1111381  is inside a tag.
# 883236  is inside a tag.
# 1246901  is inside a tag.
# 279507  is inside a tag.
# 279570  is inside a tag.
# 282454  is inside a tag.
# 1077485  is inside a tag.
# 344620  is inside a tag.
# 1418255  is inside a tag.
# 1338876  is inside a tag.
# 670716  is inside a tag.
# 431766  is inside a tag.
# 501261  is inside a tag.
# 62065  is inside a tag.
# 328525  is inside a tag.
# 1291025  is inside a tag.
# 690716  is inside a tag.
# 431766  is inside a tag.
# 580670  is inside a tag.
# 233819  is inside a tag.
# 234081  is inside a tag.
# 287752  is inside a tag.
# 982867  is inside a tag.
# 431766  is inside a tag.
# 1387513  is inside a tag.
# 431766  is inside a tag.
# 1419780  is inside a tag.
# 385037  is inside a tag.
# 431766  is inside a tag.
# 697813  is inside a tag.
# 107653  is inside a tag.
# 1077485  is inside a tag.
# 1077673  is inside a tag.
# 25042  is inside a tag.
# 1457325  is inside a tag.
# 431766  is inside a tag.
# 385037  is inside a tag.
# 388695  is inside a tag.
# 1279162  is inside a tag.
# 1182264  is inside a tag.
# 1077673  is inside a tag.
# 1337013  is inside a tag.
# 1337068  is inside a tag.
# 392641  is inside a tag.
# 347640  is inside a tag.
# 1247091  is inside a tag.
# 406717  is inside a tag.
# 406800  is inside a tag.
# 351529  is inside a tag.
# 382521  is inside a tag.
# 596908  is inside a tag.
# 431777  is inside a tag.
# 429634  is inside a tag.
# 552053  is inside a tag.
# 328525  is inside a tag.
# 962339  is inside a tag.
# 960877  is inside a tag.
# 960972  is inside a tag.
# 962339  is inside a tag.
# 35249  is inside a tag.
# 405233  is inside a tag.
# 996259  is inside a tag.
# 996388  is inside a tag.
# 431766  is inside a tag.
# 1344656  is inside a tag.
# 350870  is inside a tag.
# 381092  is inside a tag.
# 431766  is inside a tag.
# 282454  is inside a tag.
# 465054  is inside a tag.
# 1457295  is inside a tag.
# 643  is inside a tag.
# 544290  is inside a tag.
# 992707  is inside a tag.
# 1043910  is inside a tag.
# 1420237  is inside a tag.
# 431766  is inside a tag.
# 643  is inside a tag.
# 32087  is inside a tag.
# 363913  is inside a tag.
# 883258  is inside a tag.
# 950395  is inside a tag.
# 638649  is inside a tag.
# 639201  is inside a tag.
# 1123654  is inside a tag.
# 1123723  is inside a tag.
# 169262  is inside a tag.
# 425506  is inside a tag.
# 425507  is inside a tag.
# 1144196  is inside a tag.
# 643  is inside a tag.
# 1336838  is inside a tag.
# 1338876  is inside a tag.
# 1372501  is inside a tag.
# 357064  is inside a tag.
# 643  is inside a tag.
# 406717  is inside a tag.
# 406800  is inside a tag.
# 280329  is inside a tag.
# 67122  is inside a tag.
# 593864  is inside a tag.
# 1458924  is inside a tag.
# 775900  is inside a tag.
# 781132  is inside a tag.
# 277380  is inside a tag.
# 281960  is inside a tag.
# 813  is inside a tag.
# 411297  is inside a tag.
# 1407693  is inside a tag.
# 351529  is inside a tag.
# 771028  is inside a tag.
# 173986  is inside a tag.
# 25690  is inside a tag.
# 1238422  is inside a tag.
# 647442  is inside a tag.
# 643  is inside a tag.
# 35155  is inside a tag.
# 873514  is inside a tag.
# 1151741  is inside a tag.
# 883941  is inside a tag.
# 884065  is inside a tag.
# 643  is inside a tag.
# 405233  is inside a tag.
# 674503  is inside a tag.
# 1171042  is inside a tag.
# 431766  is inside a tag.
# 1291025  is inside a tag.
# 675901  is inside a tag.
# 702832  is inside a tag.
# 282751  is inside a tag.
# 501261  is inside a tag.
# 495575  is inside a tag.
# 431766  is inside a tag.
# 1146387  is inside a tag.
# 1246846  is inside a tag.
# 1247091  is inside a tag.
# 282454  is inside a tag.
# 109583  is inside a tag.
# 648991  is inside a tag.
# 771028  is inside a tag.
# 425458  is inside a tag.
# 400558  is inside a tag.
# 67122  is inside a tag.
# 431766  is inside a tag.
# 1214427  is inside a tag.
# 257736  is inside a tag.
# 353747  is inside a tag.
# 1000275  is inside a tag.
# 407240  is inside a tag.
# 407328  is inside a tag.
# 575809  is inside a tag.
# 406943  is inside a tag.
# 111995  is inside a tag.
# 960253  is inside a tag.
# 1246846  is inside a tag.
# 1418255  is inside a tag.
# 595254  is inside a tag.
# 620991  is inside a tag.
# 960799  is inside a tag.
# 975494  is inside a tag.
# 775417  is inside a tag.
# 392582  is inside a tag.
# 431766  is inside a tag.
# 1123654  is inside a tag.
# 1123747  is inside a tag.
# 242657  is inside a tag.
# 813  is inside a tag.
# 648810  is inside a tag.
# 510212  is inside a tag.
# 242675  is inside a tag.
# 921210  is inside a tag.
# 996388  is inside a tag.
# 643  is inside a tag.
# 883494  is inside a tag.
# 610076  is inside a tag.
# 615669  is inside a tag.
# 4642  is inside a tag.
# 960131  is inside a tag.
# 1407682  is inside a tag.
# 171652  is inside a tag.
# 173986  is inside a tag.
# 890849  is inside a tag.
# 452015  is inside a tag.
# 81476  is inside a tag.
# 463590  is inside a tag.
# 1214450  is inside a tag.
# 429706  is inside a tag.
# 431766  is inside a tag.
# 811368  is inside a tag.
# 962339  is inside a tag.
# 873627  is inside a tag.
# 1407678  is inside a tag.
# 1419895  is inside a tag.
# 1420127  is inside a tag.
# 392567  is inside a tag.
# 392582  is inside a tag.
# 251770  is inside a tag.
# 328525  is inside a tag.
# 1065778  is inside a tag.
# 328525  is inside a tag.
# 441817  is inside a tag.
# 382521  is inside a tag.
# 995144  is inside a tag.
# 282751  is inside a tag.
# 1123436  is inside a tag.
# 328525  is inside a tag.
# 1407702  is inside a tag.
# True     5321
# False     219
# Name: loc, dtype: int64

# %%
dfMelted['locCorrected'] = dfMelted['loc'].apply(avoidTags)
# Out:
# 1208681  is inside a tag.
# 940508  is inside a tag.
# 425458  is inside a tag.
# 1246846  is inside a tag.
# 657372  is inside a tag.
# 279507  is inside a tag.
# 343592  is inside a tag.
# 350877  is inside a tag.
# 380573  is inside a tag.
# 1458924  is inside a tag.
# 1460047  is inside a tag.
# 1153319  is inside a tag.
# 962339  is inside a tag.
# 776232  is inside a tag.
# 1146398  is inside a tag.
# 445923  is inside a tag.
# 452075  is inside a tag.
# 693604  is inside a tag.
# 1108743  is inside a tag.
# 1460034  is inside a tag.
# 530677  is inside a tag.
# 783383  is inside a tag.
# 830205  is inside a tag.
# 830326  is inside a tag.
# 280329  is inside a tag.
# 281386  is inside a tag.
# 385037  is inside a tag.
# 405233  is inside a tag.
# 429706  is inside a tag.
# 961731  is inside a tag.
# 962339  is inside a tag.
# 1346423  is inside a tag.
# 431766  is inside a tag.
# 431766  is inside a tag.
# 274032  is inside a tag.
# 1125421  is inside a tag.
# 431766  is inside a tag.
# 331088  is inside a tag.
# 330878  is inside a tag.
# 646366  is inside a tag.
# 1428771  is inside a tag.
# 517886  is inside a tag.
# 279486  is inside a tag.
# 274141  is inside a tag.
# 923112  is inside a tag.
# 1111381  is inside a tag.
# 883236  is inside a tag.
# 1246901  is inside a tag.
# 279507  is inside a tag.
# 279570  is inside a tag.
# 282454  is inside a tag.
# 1077485  is inside a tag.
# 344620  is inside a tag.
# 1418255  is inside a tag.
# 1338876  is inside a tag.
# 670716  is inside a tag.
# 431766  is inside a tag.
# 501261  is inside a tag.
# 62065  is inside a tag.
# 328525  is inside a tag.
# 1291025  is inside a tag.
# 690716  is inside a tag.
# 431766  is inside a tag.
# 580670  is inside a tag.
# 233819  is inside a tag.
# 234081  is inside a tag.
# 287752  is inside a tag.
# 982867  is inside a tag.
# 431766  is inside a tag.
# 1387513  is inside a tag.
# 431766  is inside a tag.
# 1419780  is inside a tag.
# 385037  is inside a tag.
# 431766  is inside a tag.
# 697813  is inside a tag.
# 107653  is inside a tag.
# 1077485  is inside a tag.
# 1077673  is inside a tag.
# 25042  is inside a tag.
# 1457325  is inside a tag.
# 431766  is inside a tag.
# 385037  is inside a tag.
# 388695  is inside a tag.
# 1279162  is inside a tag.
# 1182264  is inside a tag.
# 1077673  is inside a tag.
# 1337013  is inside a tag.
# 1337068  is inside a tag.
# 392641  is inside a tag.
# 347640  is inside a tag.
# 1247091  is inside a tag.
# 406717  is inside a tag.
# 406800  is inside a tag.
# 351529  is inside a tag.
# 382521  is inside a tag.
# 596908  is inside a tag.
# 431777  is inside a tag.
# 429634  is inside a tag.
# 552053  is inside a tag.
# 328525  is inside a tag.
# 962339  is inside a tag.
# 960877  is inside a tag.
# 960972  is inside a tag.
# 962339  is inside a tag.
# 35249  is inside a tag.
# 405233  is inside a tag.
# 996259  is inside a tag.
# 996388  is inside a tag.
# 431766  is inside a tag.
# 1344656  is inside a tag.
# 350870  is inside a tag.
# 381092  is inside a tag.
# 431766  is inside a tag.
# 282454  is inside a tag.
# 465054  is inside a tag.
# 1457295  is inside a tag.
# 643  is inside a tag.
# 544290  is inside a tag.
# 992707  is inside a tag.
# 1043910  is inside a tag.
# 1420237  is inside a tag.
# 431766  is inside a tag.
# 643  is inside a tag.
# 32087  is inside a tag.
# 363913  is inside a tag.
# 883258  is inside a tag.
# 950395  is inside a tag.
# 638649  is inside a tag.
# 639201  is inside a tag.
# 1123654  is inside a tag.
# 1123723  is inside a tag.
# 169262  is inside a tag.
# 425506  is inside a tag.
# 425507  is inside a tag.
# 1144196  is inside a tag.
# 643  is inside a tag.
# 1336838  is inside a tag.
# 1338876  is inside a tag.
# 1372501  is inside a tag.
# 357064  is inside a tag.
# 643  is inside a tag.
# 406717  is inside a tag.
# 406800  is inside a tag.
# 280329  is inside a tag.
# 67122  is inside a tag.
# 593864  is inside a tag.
# 1458924  is inside a tag.
# 775900  is inside a tag.
# 781132  is inside a tag.
# 277380  is inside a tag.
# 281960  is inside a tag.
# 813  is inside a tag.
# 411297  is inside a tag.
# 1407693  is inside a tag.
# 351529  is inside a tag.
# 771028  is inside a tag.
# 173986  is inside a tag.
# 25690  is inside a tag.
# 1238422  is inside a tag.
# 647442  is inside a tag.
# 643  is inside a tag.
# 35155  is inside a tag.
# 873514  is inside a tag.
# 1151741  is inside a tag.
# 883941  is inside a tag.
# 884065  is inside a tag.
# 643  is inside a tag.
# 405233  is inside a tag.
# 674503  is inside a tag.
# 1171042  is inside a tag.
# 431766  is inside a tag.
# 1291025  is inside a tag.
# 675901  is inside a tag.
# 702832  is inside a tag.
# 282751  is inside a tag.
# 501261  is inside a tag.
# 495575  is inside a tag.
# 431766  is inside a tag.
# 1146387  is inside a tag.
# 1246846  is inside a tag.
# 1247091  is inside a tag.
# 282454  is inside a tag.
# 109583  is inside a tag.
# 648991  is inside a tag.
# 771028  is inside a tag.
# 425458  is inside a tag.
# 400558  is inside a tag.
# 67122  is inside a tag.
# 431766  is inside a tag.
# 1214427  is inside a tag.
# 257736  is inside a tag.
# 353747  is inside a tag.
# 1000275  is inside a tag.
# 407240  is inside a tag.
# 407328  is inside a tag.
# 575809  is inside a tag.
# 406943  is inside a tag.
# 111995  is inside a tag.
# 960253  is inside a tag.
# 1246846  is inside a tag.
# 1418255  is inside a tag.
# 595254  is inside a tag.
# 620991  is inside a tag.
# 960799  is inside a tag.
# 975494  is inside a tag.
# 775417  is inside a tag.
# 392582  is inside a tag.
# 431766  is inside a tag.
# 1123654  is inside a tag.
# 1123747  is inside a tag.
# 242657  is inside a tag.
# 813  is inside a tag.
# 648810  is inside a tag.
# 510212  is inside a tag.
# 242675  is inside a tag.
# 921210  is inside a tag.
# 996388  is inside a tag.
# 643  is inside a tag.
# 883494  is inside a tag.
# 610076  is inside a tag.
# 615669  is inside a tag.
# 4642  is inside a tag.
# 960131  is inside a tag.
# 1407682  is inside a tag.
# 171652  is inside a tag.
# 173986  is inside a tag.
# 890849  is inside a tag.
# 452015  is inside a tag.
# 81476  is inside a tag.
# 463590  is inside a tag.
# 1214450  is inside a tag.
# 429706  is inside a tag.
# 431766  is inside a tag.
# 811368  is inside a tag.
# 962339  is inside a tag.
# 873627  is inside a tag.
# 1407678  is inside a tag.
# 1419895  is inside a tag.
# 1420127  is inside a tag.
# 392567  is inside a tag.
# 392582  is inside a tag.
# 251770  is inside a tag.
# 328525  is inside a tag.
# 1065778  is inside a tag.
# 328525  is inside a tag.
# 441817  is inside a tag.
# 382521  is inside a tag.
# 995144  is inside a tag.
# 282751  is inside a tag.
# 1123436  is inside a tag.
# 328525  is inside a tag.
# 1407702  is inside a tag.

# %%
len(fw)
# Out:
# 1465021

# %%
dfMelted['loc'].max()
# Out:
# 1460174

# %%
dfMelted.sort_values(by='locCorrected')
# Out:
#                                                                       Text A  \
# 480(643, 800)start         ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 916(643, 800)start         ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 677(643, 1000)start        ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 586(643, 713)start         ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 665(643, 787)start         ../texts/corpus-joyce-finnegans-wake-tei/finne...
# ...                                                                      ...
# 1101(1459974, 1460174)end  ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 464(1459735, 1460174)end   ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 359(1460111, 1460174)end   ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 589(1459918, 1460174)end   ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 83(1460034, 1460174)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
#
#                                                                       Text B  \
# 480(643, 800)start         /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 916(643, 800)start         /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 677(643, 1000)start        /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 586(643, 713)start         /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 665(643, 787)start         /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# ...                                                                      ...
# 1101(1459974, 1460174)end  /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 464(1459735, 1460174)end   /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 359(1460111, 1460174)end   /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 589(1459918, 1460174)end   /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 83(1460034, 1460174)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
#
#                           Threshold Cutoff N-Grams Num Matches Text A Length  \
# 480(643, 800)start                3      5       3           6       1460281
# 916(643, 800)start                3      5       3           1       1460281
# 677(643, 1000)start               3      5       3           2       1460281
# 586(643, 713)start                3      5       3           1       1460281
# 665(643, 787)start                3      5       3           1       1460281
# ...                             ...    ...     ...         ...           ...
# 1101(1459974, 1460174)end         3      5       3           1       1460281
# 464(1459735, 1460174)end          3      5       3           8       1460281
# 359(1460111, 1460174)end          3      5       3           1       1460281
# 589(1459918, 1460174)end          3      5       3           4       1460281
# 83(1460034, 1460174)end           3      5       3           3       1460281
#
#                           Text B Length  \
# 480(643, 800)start                63300
# 916(643, 800)start                26389
# 677(643, 1000)start              109733
# 586(643, 713)start                46120
# 665(643, 787)start                 4724
# ...                                 ...
# 1101(1459974, 1460174)end         21855
# 464(1459735, 1460174)end          93927
# 359(1460111, 1460174)end           2386
# 589(1459918, 1460174)end          46419
# 83(1460034, 1460174)end           14198
#
#                                                               Locations in A  \
# 480(643, 800)start         [(643, 800), (873885, 873940), (877420, 877517...
# 916(643, 800)start                                              [(643, 800)]
# 677(643, 1000)start                          [(643, 1000), (453652, 453874)]
# 586(643, 713)start                                              [(643, 713)]
# 665(643, 787)start                                              [(643, 787)]
# ...                                                                      ...
# 1101(1459974, 1460174)end                               [(1459974, 1460174)]
# 464(1459735, 1460174)end   [(1692, 2184), (5121, 5348), (48971, 49265), (...
# 359(1460111, 1460174)end                                [(1460111, 1460174)]
# 589(1459918, 1460174)end   [(1458992, 1459379), (1459411, 1459794), (1459...
# 83(1460034, 1460174)end    [(679, 800), (879875, 879942), (1460034, 14601...
#
#                                                               Locations in B  \
# 480(643, 800)start         [(115, 264), (4913, 4968), (5455, 5552), (5774...
# 916(643, 800)start                                          [(22222, 22371)]
# 677(643, 1000)start                         [(35538, 35867), (58200, 58384)]
# 586(643, 713)start                                            [(7240, 7304)]
# 665(643, 787)start                                             [(909, 1044)]
# ...                                                                      ...
# 1101(1459974, 1460174)end                                   [(10224, 10412)]
# 464(1459735, 1460174)end   [(45419, 45885), (57581, 57792), (59472, 59751...
# 359(1460111, 1460174)end                                      [(1811, 1871)]
# 589(1459918, 1460174)end   [(42822, 43180), (43213, 43574), (43425, 43675...
# 83(1460034, 1460174)end           [(3806, 3919), (6421, 6484), (7785, 7918)]
#
#                                loc locType  locCorrected
# 480(643, 800)start             643   start           643
# 916(643, 800)start             643   start           643
# 677(643, 1000)start            643   start           643
# 586(643, 713)start             643   start           643
# 665(643, 787)start             643   start           643
# ...                            ...     ...           ...
# 1101(1459974, 1460174)end  1460174     end       1460174
# 464(1459735, 1460174)end   1460174     end       1460174
# 359(1460111, 1460174)end   1460174     end       1460174
# 589(1459918, 1460174)end   1460174     end       1460174
# 83(1460034, 1460174)end    1460174     end       1460174
#
# [5540 rows x 13 columns]

# %%
def showContext(loc, n=100): 
    print(fw[loc-n:loc]+'-XXX-'+fw[loc+n])

# %%
showContext(585870)
# Out:
#  heavy Humph with airy Nan,
#     Ricqueracqbrimbillyjicqueyjocqjolicass? How sowesthow,
#     <hi rendi-XXX-s

# %% [markdown]
# - Go through each character in FW
# - And Go through each locCorrected
# - Is the character the same as our locCorrected?
#   - Is it a start?
#     - Start a `<span>`. Give it all the metadata.
#   - Is it an end?
#     - Do a `</span>`. Give it metadata.
#   - If so, start a span. Give it all the metadata.
# - Is the character the beginning of a tag?
#   - Raise a flag to indicate that we're inside a tag
#   - Keep going until we see the end of the tag

# %%
def buildAnchor(df): 
    fileNames = " ".join([re.sub('/home/jon/Code/corpus-joyce-finnegans-wake-tei/criticism-analysis/\d/ocr/', '', fn) 
                 for fn in df['Text B'].values])
    indices = " ".join(list(df.index))
    locTypes = df['locType'][0] # We can get away with using [0] since these are only of one type 
    anchor = f'<anchor xml:id="{indices}" corresp="{fileNames}" type="{locTypes}"/>'
    return anchor

def buildSpan(df): 
    fileNames = " ".join([re.sub('/home/jon/Code/corpus-joyce-finnegans-wake-tei/criticism-analysis/\d/ocr/', '', fn) 
                 for fn in df['Text B'].values])
    indices = " ".join(list(df.index))
    nQuotes = len(df.index)
    locType = df['locType'][0] # We can get away with using [0] since these are only of one type 
    if locTypes == 'start': 
        return f'<span data-location="{indices}" data-filenames="{fileNames}" data-n-quotes="{nQuotes}">'
    if locTypes == 'end': 
        return f'</span>'

# %%
df['Locations in A']
# Out:
# 0                                      [(334922, 335011)]
# 1                                      [(478048, 478132)]
# 2                                          [(5475, 5947)]
# 3       [(296676, 296759), (1122825, 1123526), (120332...
# 4                                      [(177213, 177359)]
#                               ...
# 1135    [(465107, 465196), (496432, 496604), (496874, ...
# 1136                                   [(437465, 437691)]
# 1137                                   [(147036, 147196)]
# 1138    [(244562, 245048), (408888, 408993), (788319, ...
# 1139                                   [(366179, 366282)]
# Name: Locations in A, Length: 1140, dtype: object

# %%
dfMelted
# Out:
#                                                                       Text A  \
# 0(334922, 335011)start     ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 0(334922, 335011)end       ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1(478048, 478132)start     ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1(478048, 478132)end       ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 2(5475, 5947)start         ../texts/corpus-joyce-finnegans-wake-tei/finne...
# ...                                                                      ...
# 1138(408888, 408993)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1138(788319, 788414)start  ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1138(788319, 788414)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1139(366179, 366282)start  ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1139(366179, 366282)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
#
#                                                                       Text B  \
# 0(334922, 335011)start     /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 0(334922, 335011)end       /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1(478048, 478132)start     /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1(478048, 478132)end       /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 2(5475, 5947)start         /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# ...                                                                      ...
# 1138(408888, 408993)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1138(788319, 788414)start  /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1138(788319, 788414)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1139(366179, 366282)start  /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1139(366179, 366282)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
#
#                           Threshold Cutoff N-Grams Num Matches Text A Length  \
# 0(334922, 335011)start            3      5       3           1       1460281
# 0(334922, 335011)end              3      5       3           1       1460281
# 1(478048, 478132)start            3      5       3           1       1460281
# 1(478048, 478132)end              3      5       3           1       1460281
# 2(5475, 5947)start                3      5       3           1       1460281
# ...                             ...    ...     ...         ...           ...
# 1138(408888, 408993)end           3      5       3           3       1460281
# 1138(788319, 788414)start         3      5       3           3       1460281
# 1138(788319, 788414)end           3      5       3           3       1460281
# 1139(366179, 366282)start         3      5       3           1       1460281
# 1139(366179, 366282)end           3      5       3           1       1460281
#
#                           Text B Length  \
# 0(334922, 335011)start            48541
# 0(334922, 335011)end              48541
# 1(478048, 478132)start            61396
# 1(478048, 478132)end              61396
# 2(5475, 5947)start                42828
# ...                                 ...
# 1138(408888, 408993)end           56651
# 1138(788319, 788414)start         56651
# 1138(788319, 788414)end           56651
# 1139(366179, 366282)start          5082
# 1139(366179, 366282)end            5082
#
#                                                               Locations in A  \
# 0(334922, 335011)start                                    [(334922, 335011)]
# 0(334922, 335011)end                                      [(334922, 335011)]
# 1(478048, 478132)start                                    [(478048, 478132)]
# 1(478048, 478132)end                                      [(478048, 478132)]
# 2(5475, 5947)start                                            [(5475, 5947)]
# ...                                                                      ...
# 1138(408888, 408993)end    [(244562, 245048), (408888, 408993), (788319, ...
# 1138(788319, 788414)start  [(244562, 245048), (408888, 408993), (788319, ...
# 1138(788319, 788414)end    [(244562, 245048), (408888, 408993), (788319, ...
# 1139(366179, 366282)start                                 [(366179, 366282)]
# 1139(366179, 366282)end                                   [(366179, 366282)]
#
#                                                            Locations in B  \
# 0(334922, 335011)start                                     [(2215, 2297)]
# 0(334922, 335011)end                                       [(2215, 2297)]
# 1(478048, 478132)start                                   [(47617, 47697)]
# 1(478048, 478132)end                                     [(47617, 47697)]
# 2(5475, 5947)start                                       [(28220, 28665)]
# ...                                                                   ...
# 1138(408888, 408993)end    [(2307, 2765), (27890, 27992), (28206, 28297)]
# 1138(788319, 788414)start  [(2307, 2765), (27890, 27992), (28206, 28297)]
# 1138(788319, 788414)end    [(2307, 2765), (27890, 27992), (28206, 28297)]
# 1139(366179, 366282)start                                  [(3206, 3305)]
# 1139(366179, 366282)end                                    [(3206, 3305)]
#
#                               loc locType  locCorrected
# 0(334922, 335011)start     334922   start        334922
# 0(334922, 335011)end       335011     end        335011
# 1(478048, 478132)start     478048   start        478048
# 1(478048, 478132)end       478132     end        478132
# 2(5475, 5947)start           5475   start          5475
# ...                           ...     ...           ...
# 1138(408888, 408993)end    408993     end        408993
# 1138(788319, 788414)start  788319   start        788319
# 1138(788319, 788414)end    788414     end        788414
# 1139(366179, 366282)start  366179   start        366179
# 1139(366179, 366282)end    366282     end        366282
#
# [5540 rows x 13 columns]

# %%
5475 in dfMelted['locCorrected'].values
# Out:
# True

# %%
dfMelted['locCorrected'].values
# Out:
# array([334922, 335011, 478048, ..., 788414, 366179, 366282])

# %%
ranges = []
for i, row in df['Locations in A'].apply(eval).iteritems(): 
#    print(i, row)
    for loc in row: 
        ranges.append((i, loc[0], loc[1]))
#ranges

# %%
starts = dfMelted[dfMelted['locType'] == 'start']['locCorrected'].values
ends = dfMelted[dfMelted['locType'] == 'end']['locCorrected'].values

# %%
788414 in ends
# Out:
# True

# %%
dfMelted
# Out:
#                                                                       Text A  \
# 0(334922, 335011)start     ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 0(334922, 335011)end       ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1(478048, 478132)start     ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1(478048, 478132)end       ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 2(5475, 5947)start         ../texts/corpus-joyce-finnegans-wake-tei/finne...
# ...                                                                      ...
# 1138(408888, 408993)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1138(788319, 788414)start  ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1138(788319, 788414)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1139(366179, 366282)start  ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1139(366179, 366282)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
#
#                                                                       Text B  \
# 0(334922, 335011)start     /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 0(334922, 335011)end       /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1(478048, 478132)start     /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1(478048, 478132)end       /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 2(5475, 5947)start         /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# ...                                                                      ...
# 1138(408888, 408993)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1138(788319, 788414)start  /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1138(788319, 788414)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1139(366179, 366282)start  /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1139(366179, 366282)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
#
#                           Threshold Cutoff N-Grams Num Matches Text A Length  \
# 0(334922, 335011)start            3      5       3           1       1460281
# 0(334922, 335011)end              3      5       3           1       1460281
# 1(478048, 478132)start            3      5       3           1       1460281
# 1(478048, 478132)end              3      5       3           1       1460281
# 2(5475, 5947)start                3      5       3           1       1460281
# ...                             ...    ...     ...         ...           ...
# 1138(408888, 408993)end           3      5       3           3       1460281
# 1138(788319, 788414)start         3      5       3           3       1460281
# 1138(788319, 788414)end           3      5       3           3       1460281
# 1139(366179, 366282)start         3      5       3           1       1460281
# 1139(366179, 366282)end           3      5       3           1       1460281
#
#                           Text B Length  \
# 0(334922, 335011)start            48541
# 0(334922, 335011)end              48541
# 1(478048, 478132)start            61396
# 1(478048, 478132)end              61396
# 2(5475, 5947)start                42828
# ...                                 ...
# 1138(408888, 408993)end           56651
# 1138(788319, 788414)start         56651
# 1138(788319, 788414)end           56651
# 1139(366179, 366282)start          5082
# 1139(366179, 366282)end            5082
#
#                                                               Locations in A  \
# 0(334922, 335011)start                                    [(334922, 335011)]
# 0(334922, 335011)end                                      [(334922, 335011)]
# 1(478048, 478132)start                                    [(478048, 478132)]
# 1(478048, 478132)end                                      [(478048, 478132)]
# 2(5475, 5947)start                                            [(5475, 5947)]
# ...                                                                      ...
# 1138(408888, 408993)end    [(244562, 245048), (408888, 408993), (788319, ...
# 1138(788319, 788414)start  [(244562, 245048), (408888, 408993), (788319, ...
# 1138(788319, 788414)end    [(244562, 245048), (408888, 408993), (788319, ...
# 1139(366179, 366282)start                                 [(366179, 366282)]
# 1139(366179, 366282)end                                   [(366179, 366282)]
#
#                                                            Locations in B  \
# 0(334922, 335011)start                                     [(2215, 2297)]
# 0(334922, 335011)end                                       [(2215, 2297)]
# 1(478048, 478132)start                                   [(47617, 47697)]
# 1(478048, 478132)end                                     [(47617, 47697)]
# 2(5475, 5947)start                                       [(28220, 28665)]
# ...                                                                   ...
# 1138(408888, 408993)end    [(2307, 2765), (27890, 27992), (28206, 28297)]
# 1138(788319, 788414)start  [(2307, 2765), (27890, 27992), (28206, 28297)]
# 1138(788319, 788414)end    [(2307, 2765), (27890, 27992), (28206, 28297)]
# 1139(366179, 366282)start                                  [(3206, 3305)]
# 1139(366179, 366282)end                                    [(3206, 3305)]
#
#                               loc locType  locCorrected  matchID
# 0(334922, 335011)start     334922   start        334922        0
# 0(334922, 335011)end       335011     end        335011        0
# 1(478048, 478132)start     478048   start        478048        1
# 1(478048, 478132)end       478132     end        478132        1
# 2(5475, 5947)start           5475   start          5475        2
# ...                           ...     ...           ...      ...
# 1138(408888, 408993)end    408993     end        408993     1138
# 1138(788319, 788414)start  788319   start        788319     1138
# 1138(788319, 788414)end    788414     end        788414     1138
# 1139(366179, 366282)start  366179   start        366179     1139
# 1139(366179, 366282)end    366282     end        366282     1139
#
# [5540 rows x 14 columns]

# %%
# Extract match ID again
dfMelted['matchID'] = [re.sub('(start|end)', '', item) for item in list(dfMelted.index)]

# %%
# Out:
# '0(334922, 335011)'

# %%
dfMelted
# Out:
#                                                                       Text A  \
# 0(334922, 335011)start     ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 0(334922, 335011)end       ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1(478048, 478132)start     ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1(478048, 478132)end       ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 2(5475, 5947)start         ../texts/corpus-joyce-finnegans-wake-tei/finne...
# ...                                                                      ...
# 1138(408888, 408993)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1138(788319, 788414)start  ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1138(788319, 788414)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1139(366179, 366282)start  ../texts/corpus-joyce-finnegans-wake-tei/finne...
# 1139(366179, 366282)end    ../texts/corpus-joyce-finnegans-wake-tei/finne...
#
#                                                                       Text B  \
# 0(334922, 335011)start     /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 0(334922, 335011)end       /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1(478048, 478132)start     /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1(478048, 478132)end       /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 2(5475, 5947)start         /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# ...                                                                      ...
# 1138(408888, 408993)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1138(788319, 788414)start  /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1138(788319, 788414)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1139(366179, 366282)start  /home/jon/Code/corpus-joyce-finnegans-wake-tei...
# 1139(366179, 366282)end    /home/jon/Code/corpus-joyce-finnegans-wake-tei...
#
#                           Threshold Cutoff N-Grams Num Matches Text A Length  \
# 0(334922, 335011)start            3      5       3           1       1460281
# 0(334922, 335011)end              3      5       3           1       1460281
# 1(478048, 478132)start            3      5       3           1       1460281
# 1(478048, 478132)end              3      5       3           1       1460281
# 2(5475, 5947)start                3      5       3           1       1460281
# ...                             ...    ...     ...         ...           ...
# 1138(408888, 408993)end           3      5       3           3       1460281
# 1138(788319, 788414)start         3      5       3           3       1460281
# 1138(788319, 788414)end           3      5       3           3       1460281
# 1139(366179, 366282)start         3      5       3           1       1460281
# 1139(366179, 366282)end           3      5       3           1       1460281
#
#                           Text B Length  \
# 0(334922, 335011)start            48541
# 0(334922, 335011)end              48541
# 1(478048, 478132)start            61396
# 1(478048, 478132)end              61396
# 2(5475, 5947)start                42828
# ...                                 ...
# 1138(408888, 408993)end           56651
# 1138(788319, 788414)start         56651
# 1138(788319, 788414)end           56651
# 1139(366179, 366282)start          5082
# 1139(366179, 366282)end            5082
#
#                                                               Locations in A  \
# 0(334922, 335011)start                                    [(334922, 335011)]
# 0(334922, 335011)end                                      [(334922, 335011)]
# 1(478048, 478132)start                                    [(478048, 478132)]
# 1(478048, 478132)end                                      [(478048, 478132)]
# 2(5475, 5947)start                                            [(5475, 5947)]
# ...                                                                      ...
# 1138(408888, 408993)end    [(244562, 245048), (408888, 408993), (788319, ...
# 1138(788319, 788414)start  [(244562, 245048), (408888, 408993), (788319, ...
# 1138(788319, 788414)end    [(244562, 245048), (408888, 408993), (788319, ...
# 1139(366179, 366282)start                                 [(366179, 366282)]
# 1139(366179, 366282)end                                   [(366179, 366282)]
#
#                                                            Locations in B  \
# 0(334922, 335011)start                                     [(2215, 2297)]
# 0(334922, 335011)end                                       [(2215, 2297)]
# 1(478048, 478132)start                                   [(47617, 47697)]
# 1(478048, 478132)end                                     [(47617, 47697)]
# 2(5475, 5947)start                                       [(28220, 28665)]
# ...                                                                   ...
# 1138(408888, 408993)end    [(2307, 2765), (27890, 27992), (28206, 28297)]
# 1138(788319, 788414)start  [(2307, 2765), (27890, 27992), (28206, 28297)]
# 1138(788319, 788414)end    [(2307, 2765), (27890, 27992), (28206, 28297)]
# 1139(366179, 366282)start                                  [(3206, 3305)]
# 1139(366179, 366282)end                                    [(3206, 3305)]
#
#                               loc locType  locCorrected               matchID
# 0(334922, 335011)start     334922   start        334922     0(334922, 335011)
# 0(334922, 335011)end       335011     end        335011     0(334922, 335011)
# 1(478048, 478132)start     478048   start        478048     1(478048, 478132)
# 1(478048, 478132)end       478132     end        478132     1(478048, 478132)
# 2(5475, 5947)start           5475   start          5475         2(5475, 5947)
# ...                           ...     ...           ...                   ...
# 1138(408888, 408993)end    408993     end        408993  1138(408888, 408993)
# 1138(788319, 788414)start  788319   start        788319  1138(788319, 788414)
# 1138(788319, 788414)end    788414     end        788414  1138(788319, 788414)
# 1139(366179, 366282)start  366179   start        366179  1139(366179, 366282)
# 1139(366179, 366282)end    366282     end        366282  1139(366179, 366282)
#
# [5540 rows x 14 columns]

# %%
# Get matches with start 
def getMatchesWithLoc(loc, locType): 
    return list(dfMelted[(dfMelted['locCorrected'] == loc) & (dfMelted['locType'] == locType)]['matchID'])

# %%
fw.index('bababadalgharaghtakammina')
# Out:
# 1574

# %%
newFW = ""
inRanges = set()
n = 0
fwSubset = fw[:fw.index('bababadalgharaghtakammina')]

def span(matches, kind='start'): 
    if len(matches) == 0: 
        return ""
    matchesStr = " ".join(set([str(match) for match in matches]))
    n = len(matches)
    if len(matchesStr.strip()) == 0: 
        return ""
    if kind == 'start': 
        return f'<!--Start--><span data-matches="{matchesStr}" data-n-quotes="{n}">'
    return f"</span><!--End of {matchesStr}-->"

# Go through each character in the text. 
for i, char in enumerate(fwSubset): 
    # Is this the start of a quote? 
    if i in starts: 
        # End anything already started, first
        if len(inRanges) > 0: 
            newFW += span(inRanges, kind='end')
        matches = getMatchesWithLoc(i, 'start')
        for match in matches: 
            # Keep track of what quotations we're in 
            inRanges.add(match)
            #print(f"Now in range: {inRanges}")
        if len(inRanges) > 0: 
            newFW += f"<!-- Starting {i} in matches {matches} -->"
            newFW += span(inRanges, kind='start')
            
        newFW += char
    # Is this the end of a quote? 
    elif i in ends and len(inRanges) > 0: 
        newFW += char
        # What ends here? 
        matches = getMatchesWithLoc(i, 'end')
        # End everything that ends here
        #print(f"{i} is an end location.")
        #print(f"Removing all of {matches}")
        if len(matches) == 0: 
            continue
        for match in matches: 
            print(f"--Removing {match} from {inRanges}")
            try: 
                inRanges.remove(match)
            except: 
                print(f"Tried to remove {match} but it's not in {inRanges}.")
                print(f"Inranges is: {inRanges} with len {len(inRanges)}")
        #print(f"Inranges is now: {inRanges}")
        newFW += span(inRanges, kind='end')
        #print(f"Inranges is now: {inRanges}")
        # Continue everything else remaining
        #print(inRanges)
        #print(f"Inranges is now: {inRanges}")
        if len(inRanges) > 0: 
            print(f"I is now {i} and Inranges is now: {inRanges}")
            newFW += f"<!-- Now at {i}. Continue everything else: {inRanges} -->"
            newFW += span(inRanges, kind='start')
    # Is this the start of some other tag? 
    elif char == '<' and len(inRanges) > 0: 
        newFW += span(inRanges, kind='end')
        newFW += "<!-- Suspending  -->"
        newFW += char
    # Is this the end of some other tag? 
    elif char == '>' and len(inRanges) > 0: 
        newFW += char
        # Resume if there's anything to resume
        newFW += "<!-- Resuming -->"
        newFW += span(inRanges, kind='start')
    else: 
        newFW += char
# Out:
# --Removing 498(643, 713) from {'586(643, 713)', '253(679, 800)', '954(679, 787)', '665(643, 787)', '297(679, 800)', '480(643, 800)', '234(679, 787)', '1001(679, 800)', '157(679, 787)', '1026(679, 800)', '990(679, 787)', '677(643, 1000)', '573(643, 800)', '83(679, 800)', '65(679, 800)', '357(679, 767)', '1046(666, 724)', '810(679, 800)', '1117(679, 800)', '66(666, 724)', '350(679, 787)', '916(643, 800)', '498(643, 713)', '544(679, 800)', '1119(679, 800)', '370(666, 724)', '680(679, 800)', '381(679, 800)', '305(666, 724)', '870(679, 800)', '606(679, 787)', '1125(679, 800)', '886(679, 833)', '872(679, 800)', '428(679, 800)', '289(679, 800)', '1063(679, 800)'}
# --Removing 810(679, 800) from {'1001(679, 800)', '1026(679, 800)', '677(643, 1000)', '810(679, 800)', '1117(679, 800)', '916(643, 800)', '1119(679, 800)', '870(679, 800)', '1125(679, 800)', '886(679, 833)', '872(679, 800)', '1063(679, 800)'}
# --Removing 870(679, 800) from {'1001(679, 800)', '1026(679, 800)', '677(643, 1000)', '1117(679, 800)', '916(643, 800)', '1119(679, 800)', '870(679, 800)', '1125(679, 800)', '886(679, 833)', '872(679, 800)', '1063(679, 800)'}
# --Removing 872(679, 800) from {'1001(679, 800)', '1026(679, 800)', '677(643, 1000)', '1117(679, 800)', '916(643, 800)', '1119(679, 800)', '1125(679, 800)', '886(679, 833)', '872(679, 800)', '1063(679, 800)'}
# --Removing 916(643, 800) from {'1001(679, 800)', '1026(679, 800)', '677(643, 1000)', '1117(679, 800)', '916(643, 800)', '1119(679, 800)', '1125(679, 800)', '886(679, 833)', '1063(679, 800)'}
# --Removing 1001(679, 800) from {'1001(679, 800)', '1026(679, 800)', '677(643, 1000)', '1117(679, 800)', '1119(679, 800)', '1125(679, 800)', '886(679, 833)', '1063(679, 800)'}
# --Removing 1026(679, 800) from {'1026(679, 800)', '677(643, 1000)', '1117(679, 800)', '1119(679, 800)', '1125(679, 800)', '886(679, 833)', '1063(679, 800)'}
# --Removing 1063(679, 800) from {'677(643, 1000)', '1117(679, 800)', '1119(679, 800)', '1125(679, 800)', '886(679, 833)', '1063(679, 800)'}
# --Removing 1117(679, 800) from {'677(643, 1000)', '1117(679, 800)', '1119(679, 800)', '1125(679, 800)', '886(679, 833)'}
# --Removing 1119(679, 800) from {'677(643, 1000)', '1119(679, 800)', '1125(679, 800)', '886(679, 833)'}
# --Removing 1125(679, 800) from {'677(643, 1000)', '1125(679, 800)', '886(679, 833)'}
# I is now 800 and Inranges is now: {'677(643, 1000)', '886(679, 833)'}
# --Removing 886(679, 833) from {'677(643, 1000)', '861(813, 1000)', '634(813, 1164)', '886(679, 833)'}
# I is now 833 and Inranges is now: {'677(643, 1000)', '861(813, 1000)', '634(813, 1164)'}
# --Removing 909(888, 970) from {'677(643, 1000)', '877(909, 1093)', '1028(888, 970)', '861(813, 1000)', '634(813, 1164)', '634(888, 1535)', '909(888, 970)', '737(888, 1000)'}
# --Removing 1028(888, 970) from {'677(643, 1000)', '877(909, 1093)', '1028(888, 970)', '861(813, 1000)', '634(813, 1164)', '634(888, 1535)', '737(888, 1000)'}
# I is now 970 and Inranges is now: {'677(643, 1000)', '877(909, 1093)', '861(813, 1000)', '634(813, 1164)', '634(888, 1535)', '737(888, 1000)'}
# --Removing 677(643, 1000) from {'677(643, 1000)', '877(909, 1093)', '861(813, 1000)', '634(813, 1164)', '634(888, 1535)', '737(888, 1000)'}
# --Removing 737(888, 1000) from {'877(909, 1093)', '861(813, 1000)', '634(813, 1164)', '634(888, 1535)', '737(888, 1000)'}
# --Removing 861(813, 1000) from {'877(909, 1093)', '861(813, 1000)', '634(813, 1164)', '634(888, 1535)'}
# I is now 1000 and Inranges is now: {'877(909, 1093)', '634(813, 1164)', '634(888, 1535)'}
# --Removing 877(909, 1093) from {'767(1030, 1164)', '1132(1030, 1164)', '877(909, 1093)', '634(813, 1164)', '634(888, 1535)', '210(1086, 1164)'}
# I is now 1093 and Inranges is now: {'767(1030, 1164)', '1132(1030, 1164)', '634(813, 1164)', '634(888, 1535)', '210(1086, 1164)'}
# --Removing 210(1086, 1164) from {'767(1030, 1164)', '1132(1030, 1164)', '634(813, 1164)', '634(888, 1535)', '210(1086, 1164)'}
# --Removing 634(813, 1164) from {'767(1030, 1164)', '1132(1030, 1164)', '634(813, 1164)', '634(888, 1535)'}
# --Removing 767(1030, 1164) from {'767(1030, 1164)', '1132(1030, 1164)', '634(888, 1535)'}
# --Removing 1132(1030, 1164) from {'1132(1030, 1164)', '634(888, 1535)'}
# I is now 1164 and Inranges is now: {'634(888, 1535)'}
# --Removing 699(1245, 1319) from {'1106(1267, 1411)', '699(1245, 1319)', '806(1245, 1319)', '634(888, 1535)', '634(1187, 1551)', '993(1245, 1319)', '463(1267, 1411)'}
# --Removing 806(1245, 1319) from {'1106(1267, 1411)', '806(1245, 1319)', '634(888, 1535)', '634(1187, 1551)', '993(1245, 1319)', '463(1267, 1411)'}
# --Removing 993(1245, 1319) from {'1106(1267, 1411)', '634(888, 1535)', '634(1187, 1551)', '993(1245, 1319)', '463(1267, 1411)'}
# I is now 1319 and Inranges is now: {'1106(1267, 1411)', '634(888, 1535)', '634(1187, 1551)', '463(1267, 1411)'}
# --Removing 838(1343, 1400) from {'903(1343, 1411)', '1106(1267, 1411)', '634(888, 1535)', '694(1343, 1411)', '838(1343, 1400)', '634(1187, 1551)', '463(1267, 1411)'}
# I is now 1400 and Inranges is now: {'903(1343, 1411)', '1106(1267, 1411)', '634(888, 1535)', '694(1343, 1411)', '634(1187, 1551)', '463(1267, 1411)'}
# --Removing 463(1267, 1411) from {'903(1343, 1411)', '1106(1267, 1411)', '634(888, 1535)', '694(1343, 1411)', '634(1187, 1551)', '463(1267, 1411)'}
# --Removing 694(1343, 1411) from {'903(1343, 1411)', '1106(1267, 1411)', '634(888, 1535)', '694(1343, 1411)', '634(1187, 1551)'}
# --Removing 903(1343, 1411) from {'903(1343, 1411)', '1106(1267, 1411)', '634(888, 1535)', '634(1187, 1551)'}
# --Removing 1106(1267, 1411) from {'1106(1267, 1411)', '634(888, 1535)', '634(1187, 1551)'}
# I is now 1411 and Inranges is now: {'634(888, 1535)', '634(1187, 1551)'}
# --Removing 425(1413, 1476) from {'425(1413, 1476)', '155(1436, 1551)', '634(888, 1535)', '634(1187, 1551)'}
# I is now 1476 and Inranges is now: {'155(1436, 1551)', '634(888, 1535)', '634(1187, 1551)'}
# --Removing 634(888, 1535) from {'155(1436, 1551)', '634(888, 1535)', '634(1187, 1551)'}
# I is now 1535 and Inranges is now: {'155(1436, 1551)', '634(1187, 1551)'}
# --Removing 155(1436, 1551) from {'155(1436, 1551)', '634(1187, 1551)'}
# --Removing 634(1187, 1551) from {'634(1187, 1551)'}

# %%
with open('../finnegans-wake-annotated.xml', 'w') as f: 
    f.write(newFW)

# %%
inRanges.remove('1071(1568, 1799)')

# %%
inRanges
# Out:
# set()
